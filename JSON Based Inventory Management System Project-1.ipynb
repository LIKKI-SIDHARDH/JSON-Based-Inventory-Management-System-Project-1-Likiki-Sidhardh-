# %%
stocks = { 1001 : {"Name": "cake" ,"Cost" : 40,"Quantity_Kg" : 10 ,"stock_boxes": 100,"Expiry_date" : "9/1/2022"},
           1002 : {"Name": "green_apple" ,"Cost" : 40,"Quantity_kg" : 1 ,"stock_boxes": 300,"Expiry_date" : "23/3/2022"},
           1003 : {"Name": "apple" ,"Cost" : 40,"Quantity_kg" : 1 ,"stock_boxes": 300,"Expiry_date" : "2/3/2022"},
           1004 : {"Name": "orange" ,"Cost" :30,"Quantity_kg" : 1 ,"stock_boxes": 400,"Expiry_date" : "6/5/2022"},
           1005 : {"Name": "grapes" ,"Cost" :35,"Quantity_kg" : 1 ,"stock_boxes": 500,"Expiry_date" :" 2/4/2022"},
           1006 : {"Name": "pineapple","Cost" :50,"Quantity_kg" : 2 ,"stock_boxes": 600,"Expiry_date" : "9/7/2022"},
           1007 : {"Name": "cream" ,"Cost" : 120,"Quantity_lit" : 1 ,"stock_boxes": 700,"Expiry_date" : "12/8/2022"},
           1008 : {"Name": "chocolate" ,"Cost" : 100,"Quantity_g" : 150 ,"stock_boxes": 800,"Expiry_date" : "19/1/2022"},
           1009 : {"Name": "floor" ,"Cost" : 69,"Quantity_kg" : 1 ,"stock_boxes": 900,"Expiry_date" : "29/8/2022"},
           1010 : {"Name": "Maggi" ,"Cost" : 45,"Quantity_g" : 750 ,"stock_boxes": 60,"Expiry_date" : "19/9/2022"},
           1011 : {"Name": "biscuit","Cost" : 20,"Quantity_g" : 100 ,"stock_boxes": 40,"Expiry_date" : '9/6/2022'},
           1012 : {"Name": "banana ","Cost" : 5,"Quantity_kg" : 1 ,"stock_boxes": 120,"Expiry_date" : "17/4/2022"},
           1013 : {"Name": "apricot" ,"Cost" : 45,"Quantity_kg" : 2 ,"stock_boxes": 160,"Expiry_date" : "11/11/2022"},
           1014 : {"Name": "avocada" ,"Cost" : 95,"Quantity_kg" : 5 ,"stock_boxes": 140,"Expiry_date" : "14/12/2022"},
           1015 : {"Name": "chocos" ,"Cost" : 65,"Quantity_kg" : 5 ,"stock_boxes": 160,"Expiry_date" : "16/12/2022"},
           1016 : {"Name": "blackberry" ,"Cost" : 50,"Quantity_kg" : 6 ,"stock_boxes": 160,"Expiry_date" : "11/11/2022"},
           1017 : {"Name": "blueberry" ,"Cost" : 45,"Quantity_kg" : 7 ,"stock_boxes": 170,"Expiry_date" : "13/5/2022"},
           1018 : {"Name": "cherry" ,"Cost" : 65,"Quantity_kg" : 1 ,"stock_boxes": 160,"Expiry_date" : "17/7/2022"},
           1019 : {"Name": "coconut" ,"Cost" : 34,"Quantity_kg" : 2 ,"stock_boxes": 190,"Expiry_date" : "23/9/2022"},
           1020 : {"Name": "grapefruit" ,"Cost" : 25,"Quantity_kg" : 5 ,"stock_boxes": 150,"Expiry_date" : "20/8/2022"},
           1021 : {"Name": "kiwi" ,"Cost" : 90,"Quantity_kg" : 7 ,"stock_boxes": 140,"Expiry_date" : "19/1/2022"},
           1022 : {"Name": "lemon" ,"Cost" : 10,"Quantity_kg" : 9 ,"stock_boxes": 120,"Expiry_date" : "9/9/2022"},
           1023 : {"Name": "lime" ,"Cost" : 12,"Quantity_kg" : 7 ,"stock_boxes": 190,"Expiry_date" : "7/4/2022"},
           1024 : {"Name": "mango" ,"Cost" : 20,"Quantity_kg" : 9 ,"stock_boxes": 110,"Expiry_date" : "1/3/2022"},
           1025 : {"Name": "papaya" ,"Cost" : 36,"Quantity_kg" : 7 ,"stock_boxes": 170,"Expiry_date" : "26/1/2022"},
           1026 : {"Name": "watermelon" ,"Cost" : 80,"Quantity_kg" : 6 ,"stock_boxes": 170,"Expiry_date" : "29/6/2022"},
           1027 : {"Name": "strawberry" ,"Cost" : 45,"Quantity_kg" : 2 ,"stock_boxes": 120,"Expiry_date" : "28/9/2022"},
           1028 : {"Name": "pomegranate" ,"Cost" : 60,"Quantity_kg" : 5 ,"stock_boxes": 190,"Expiry_date" : "28/12/2022"},
           1029 : {"Name": "raspberry" ,"Cost" : 80,"Quantity_kg" : 6 ,"stock_boxes": 160,"Expiry_date" : "4/11/2022"},
           1030 : {"Name": "fig" ,"Cost" : 69,"Quantity_kg" : 9 ,"stock_boxes": 100,"Expiry_date" : "119/11/2022"}}

# %%
import json

stock = json.dumps(stocks)

fd = open("stocks.json",'w')
fd.write(stock)
fd.close()

fd = open("stocks.json",'r')
r = fd.read()
fd.close()

stocks = json.loads(r)


print("INVENTORY MANAGEMENT")
print("--------------------")
print()
print("Available Option")
print()
print("1.Add New stocks\n2.Add New Items to Stocks\n3.billing of a product\n4.sales")
print()
i = int(input("Choose an option : "))
print()
if(i == 1):
    
        print("Add New Stocks")
        print("--------------")
        f = open("Stocks.json","w")
        prod_id = input("Enter name of the product_id : ")
        Name = input("Enter name of the product : ")
        Cost = int(input("Enter cost of the product : "))
        Quantity = int(input("Enter quantity of the product : "))
        Stock = int(input("Enter stock of the product : "))
        Expiry_date = str(input("Enter the expiry date of the product : "))
        
        values[prod_id] = {"Name" : Name, "Cost" : Cost, "Quantity" : Quantity, "stock_boxes" : Stock, "Expiry date" : Expiry_date}
              
        jdata = json.dumps(values)
        f.writelines(jdata)
        f.close()

        print("Done!!!")
        
    
elif (i == 2):
        print("Add New Items to Stocks")
        print("-----------------------")
        f = open("Stocks.json","a")
        prod_id = input("Enter name of the product_id : ")
        Name = input("Enter name of the product : ")
        Cost = int(input("Enter cost of the product : "))
        Quantity = int(input("Enter quantity of the product : "))
        Stock = int(input("Enter stock of the product : "))
        Expiry_date = str(input("Enter the expiry date of the product : "))
    
        values[prod_id] = {"Name" : Name, "Cost" : Cost, "Quantity" : Quantity, "stock_boxes" : Stock, "Expiry date" : Expiry_date}
    
        jdata = json.dumps(values)
        f.writelines(jdata)
        f.close()
    
        print("Done!!!")
        
elif (i == 3):
        ui_prod  = str(input("Enter the product_Id: "))
        ui_quant = int(input("Enter the quantity: "))
        
        print("Purchased Bill")
        print("**************")
        print("Product: ", stocks[ui_prod]['Name'])
        print("Price: ",stocks[ui_prod]['Cost'])
        print("Quant: ",ui_quant)
        print("Billing Amount: ", stocks[ui_prod]['Cost'] * ui_quant)
        print("**************")
        
        stocks[ui_prod]["stock_boxes"] = stocks[ui_prod]["stock_boxes"] - ui_quant    
        
elif (i == 4):
       
        sales = {1 : {'prod_id' : ui_prod, 'Quantity' : ui_quant, 'amount': stocks[ui_prod]['Cost'] * ui_quant}}
        sale = json.dumps(sales)
        fd = open("new_sales.json",'w')
        fd.write(sale)
        fd.close()
        print(sale)
    
else: 
    print("Not an valied option")
    print("Enter the valied option")
    print("***********************")

print()    
print("Total Stocks")
print("-----------")
f = open("Stocks.json","r")
data = f.read()
print(data)
f.close()
# Out:
# INVENTORY MANAGEMENT
# --------------------
#
# Available Option
#
# 1.Add New stocks
# 2.Add New Items to Stocks
# 3.billing of a product
# 4.sales
#
# Choose an option : 4
#
# {"1": {"prod_id": "1003", "Quantity": 4, "amount": 160}}
#
# Total Stocks
# -----------
# ...
